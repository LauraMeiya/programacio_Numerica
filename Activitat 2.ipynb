# %%
import pandas as pd
import numpy as np

delayed_flights = pd.read_csv("DelayedFlights.csv", index_col=0)
# Out:
# C:\Users\PORTATIL\anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
delayed_flights.head(10)
# Out:
#     Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0   2008      1           3          4   2003.0        1955   2211.0
# 1   2008      1           3          4    754.0         735   1002.0
# 2   2008      1           3          4    628.0         620    804.0
# 4   2008      1           3          4   1829.0        1755   1959.0
# 5   2008      1           3          4   1940.0        1915   2121.0
# 6   2008      1           3          4   1937.0        1830   2037.0
# 10  2008      1           3          4    706.0         700    916.0
# 11  2008      1           3          4   1644.0        1510   1845.0
# 15  2008      1           3          4   1029.0        1020   1021.0
# 16  2008      1           3          4   1452.0        1425   1640.0
#
#     CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0         2225            WN        335  ...    4.0      8.0        0.0
# ...

# %%
delayed_flights.tail(9)
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 6333434  2008     11          30          7   1408.0        1346   1641.0
# 6333441  2008     11          10          1   1345.0        1155   1447.0
# 6333461  2008     11           1          6    907.0         901   1103.0
# 6333478  2008     11           9          7   1149.0        1100   1336.0
# 6333479  2008     11          10          1   1148.0        1100   1313.0
# 6333499  2008     11          30          7   1135.0        1100   1301.0
# 6333507  2008     11           9          7   1406.0        1315   1717.0
# 6333528  2008     11          30          7   1344.0        1315   1757.0
# 6333540  2008     11          14          5    758.0         655    845.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 6333434        1532            NW       1448  ...    5.0     53.0        0.0
# ...

# %%
column_rellevants = delayed_flights[['Year','Month','DepTime','CRSDepTime','ArrTime','CRSArrTime','ArrDelay','Distance','Origin','AirTime']]

# %%
# Resum estadístic
column_rellevants.shape
# Out:
# (1706958, 10)

# %%
column_rellevants.describe()
# Out:
#             Year         Month       DepTime    CRSDepTime       ArrTime  \
# count  1706958.0  1.706958e+06  1.706958e+06  1.706958e+06  1.700939e+06
# mean      2008.0  5.333786e+00  1.522673e+03  1.472758e+03  1.612289e+03
# std          0.0  2.941897e+00  4.502254e+02  4.243778e+02  5.491072e+02
# min       2008.0  1.000000e+00  1.000000e+00  0.000000e+00  1.000000e+00
# 25%       2008.0  3.000000e+00  1.206000e+03  1.139000e+03  1.318000e+03
# 50%       2008.0  5.000000e+00  1.549000e+03  1.515000e+03  1.718000e+03
# 75%       2008.0  8.000000e+00  1.902000e+03  1.820000e+03  2.032000e+03
# max       2008.0  1.100000e+01  2.400000e+03  2.359000e+03  2.400000e+03
#
#          CRSArrTime      ArrDelay      Distance       AirTime
# count  1.706958e+06  1.700562e+06  1.706958e+06  1.700562e+06
# mean   1.636688e+03  4.141518e+01  7.628338e+02  1.078040e+02
# std    4.660257e+02  5.587931e+01  5.740708e+02  6.843239e+01
# min    0.000000e+00 -1.090000e+02  1.100000e+01  0.000000e+00
# ...

# %%
# Dades faltants
column_rellevants.isnull().sum()
# Out:
# Year             0
# Month            0
# DepTime          0
# CRSDepTime       0
# ArrTime       6019
# CRSArrTime       0
# ArrDelay      6396
# Distance         0
# Origin           0
# AirTime       6396
# dtype: int64

# %%
# Hi ha 6019 dades faltants en la columna ArrTime

# Afegir una columna

column_rellevants["Temps vol"] = column_rellevants["ArrTime"] - column_rellevants["DepTime"]
column_rellevants.head(10)
# Out:
# <ipython-input-106-064a21382e5f>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column_rellevants["Temps vol"] = column_rellevants["ArrTime"] - column_rellevants["DepTime"]
#     Year  Month  DepTime  CRSDepTime  ArrTime  CRSArrTime  ArrDelay  Distance  \
# 0   2008      1   2003.0        1955   2211.0        2225     -14.0       810
# 1   2008      1    754.0         735   1002.0        1000       2.0       810
# 2   2008      1    628.0         620    804.0         750      14.0       515
# 4   2008      1   1829.0        1755   1959.0        1925      34.0       515
# 5   2008      1   1940.0        1915   2121.0        2110      11.0       688
# 6   2008      1   1937.0        1830   2037.0        1940      57.0      1591
# ...

# %%
# Em pensava que restant el temps d'arrivada i de sortida sortiria el temps del vol, però hi ha valors negatius.

def retard(x):
    if x>=0:
        return "Perdoneu pel retard"
    else:
        return "Bon viatge"

column_rellevants["Retard"] = column_rellevants["ArrDelay"].apply(retard)
column_rellevants.head(10)
# Out:
# <ipython-input-107-d315cd684bc7>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column_rellevants["Retard"] = column_rellevants["ArrDelay"].apply(retard)
#     Year  Month  DepTime  CRSDepTime  ArrTime  CRSArrTime  ArrDelay  Distance  \
# 0   2008      1   2003.0        1955   2211.0        2225     -14.0       810
# 1   2008      1    754.0         735   1002.0        1000       2.0       810
# 2   2008      1    628.0         620    804.0         750      14.0       515
# 4   2008      1   1829.0        1755   1959.0        1925      34.0       515
# 5   2008      1   1940.0        1915   2121.0        2110      11.0       688
# 6   2008      1   1937.0        1830   2037.0        1940      57.0      1591
# ...

# %%
# Velocitat mitjana del vol

column_rellevants["Velocitat"] = column_rellevants["Distance"] / column_rellevants["AirTime"]
column_rellevants.head(10)
# Out:
# <ipython-input-108-3aaa8150da04>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   column_rellevants["Velocitat"] = column_rellevants["Distance"] / column_rellevants["AirTime"]
#     Year  Month  DepTime  CRSDepTime  ArrTime  CRSArrTime  ArrDelay  Distance  \
# 0   2008      1   2003.0        1955   2211.0        2225     -14.0       810
# 1   2008      1    754.0         735   1002.0        1000       2.0       810
# 2   2008      1    628.0         620    804.0         750      14.0       515
# 4   2008      1   1829.0        1755   1959.0        1925      34.0       515
# 5   2008      1   1940.0        1915   2121.0        2110      11.0       688
# 6   2008      1   1937.0        1830   2037.0        1940      57.0      1591
# ...

# %%
# Aerolínies amb més endarreriment

column_rellevants[['Origin']].value_counts().head(10)
# Out:
# Origin
# ATL       115733
# ORD       112108
# DFW        84148
# DEN        65163
# LAX        52267
# PHX        49335
# IAH        49030
# LAS        47613
# EWR        46538
# SFO        38916
# dtype: int64

# %%
# Mesos amb més retards
column_rellevants[['Month']].value_counts().head(10)
# Out:
# Month
# 6        200914
# 3        200842
# 2        189534
# 1        183527
# 7        182945
# 8        162648
# 4        155264
# 5        153072
# 10       103525
# 9         95539
# dtype: int64

# %%
# No he trobat columna d'aerolínies, però el aeroport que més ha tingut retards ha estat ATL.
# Vols més llargs

vols_llargs = column_rellevants[['AirTime']]
vols_llargs_final = vols_llargs.sort_values(by="AirTime", ascending=False)
vols_llargs_final.head()
# Out:
#          AirTime
# 5180146   1091.0
# 4614554    733.0
# 1139464    664.0
# 1742567    655.0
# 1742573    654.0

# %%
# Vols més endarrerits

vols_llargs = column_rellevants[['ArrDelay']]
vols_llargs_final = vols_llargs.sort_values(by="ArrDelay", ascending=False)
vols_llargs_final.head()
# Out:
#          ArrDelay
# 1018798    2461.0
# 2235378    2453.0
# 2832617    1951.0
# 3387883    1707.0
# 5232546    1583.0
